# %% [markdown]
# **Projet Air BNB NEW YORK dataset**

# %%
#import librairies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Charger le dataset**

# %%
df = pd.read_csv(r"C:\Users\GEORGES\Downloads\Python-Project-New-York-AirBnb\datasets.csv", encoding='utf-8')

# %% [markdown]
# **-Exploration du dataset**

# %%
#afficher les 5 premiers lignes
df.head()
# Out:
#              id                                               name    host_id  \
# 0  1.312228e+06         Rental unit in Brooklyn · ★5.0 · 1 bedroom    7130382
# 1  4.527754e+07  Rental unit in New York · ★4.67 · 2 bedrooms ·...   51501835
# 2  9.710000e+17  Rental unit in New York · ★4.17 · 1 bedroom · ...  528871354
# 3  3.857863e+06  Rental unit in New York · ★4.64 · 1 bedroom · ...   19902271
# 4  4.089661e+07  Condo in New York · ★4.91 · Studio · 1 bed · 1...   61391963
#
#             host_name neighbourhood_group       neighbourhood   latitude  \
# 0              Walter            Brooklyn        Clinton Hill  40.683710
# 1            Jeniffer           Manhattan      Hell's Kitchen  40.766610
# 2              Joshua           Manhattan             Chelsea  40.750764
# 3  John And Catherine           Manhattan  Washington Heights  40.835600
# 4      Stay With Vibe           Manhattan         Murray Hill  40.751120
#
# ...

# %%
#five last rows
df.tail()
# Out:
#                  id                                               name  \
# 20765  2.473690e+07  Rental unit in New York · ★4.75 · 1 bedroom · ...
# 20766  2.835711e+06  Rental unit in New York · ★4.46 · 1 bedroom · ...
# 20767  5.182527e+07  Rental unit in New York · ★4.93 · 1 bedroom · ...
# 20768  7.830000e+17  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 20769  5.660000e+17  Rental unit in Queens · ★4.89 · 1 bedroom · 1 ...
#
#          host_id host_name neighbourhood_group      neighbourhood   latitude  \
# 20765  186680487   Henry D           Manhattan    Lower East Side  40.711380
# 20766    3237504     Aspen           Manhattan  Greenwich Village  40.730580
# 20767  304317395      Jeff           Manhattan     Hell's Kitchen  40.757350
# 20768  163083101   Marissa           Manhattan          Chinatown  40.713750
# 20769   93827372   Glenroy              Queens           Rosedale  40.658874
#
# ...

# %%
#data rowa*columns
df.shape
# Out:
# (20770, 22)

# %%
#dato informations
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20770 entries, 0 to 20769
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20770 non-null  float64
#  1   name                            20770 non-null  object
#  2   host_id                         20770 non-null  int64
#  3   host_name                       20770 non-null  object
#  4   neighbourhood_group             20770 non-null  object
#  5   neighbourhood                   20763 non-null  object
#  6   latitude                        20763 non-null  float64
#  7   longitude                       20763 non-null  float64
#  8   room_type                       20763 non-null  object
#  9   price                           20736 non-null  float64
#  10  minimum_nights                  20763 non-null  float64
#  11  number_of_reviews               20763 non-null  float64
# ...

# %%
#statisticals summury
df.describe()
# Out:
#                  id       host_id      latitude     longitude          price  \
# count  2.077000e+04  2.077000e+04  20763.000000  20763.000000   20736.000000
# mean   3.033858e+17  1.749049e+08     40.726821    -73.939179     187.714940
# std    3.901221e+17  1.725657e+08      0.060293      0.061403    1023.245124
# min    2.595000e+03  1.678000e+03     40.500314    -74.249840      10.000000
# 25%    2.707260e+07  2.041184e+07     40.684159    -73.980755      80.000000
# 50%    4.992852e+07  1.086990e+08     40.722890    -73.949597     125.000000
# 75%    7.220000e+17  3.143997e+08     40.763106    -73.917475     199.000000
# max    1.050000e+18  5.504035e+08     40.911147    -73.713650  100000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    20763.000000       20763.000000       20763.000000
# mean        28.558493          42.610605           1.257589
# std         33.532697          73.523401           1.904472
# ...

# %%
#valeurs manquantes
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     7
# latitude                          7
# longitude                         7
# room_type                         7
# price                             0
# minimum_nights                    7
# number_of_reviews                 7
# last_review                       7
# reviews_per_month                 7
# calculated_host_listings_count    7
# availability_365                  7
# number_of_reviews_ltm             7
# license                           0
# rating                            0
# bedrooms                          0
# beds                              0
# baths                             0
# dtype: int64

# %%
for col in df.columns:
    print(col, df[col].isin(['n/a','null','?']).sum())
# Out:
# id 0
# name 0
# host_id 0
# host_name 0
# neighbourhood_group 0
# neighbourhood 0
# latitude 0
# longitude 0
# room_type 0
# price 0
# minimum_nights 0
# number_of_reviews 0
# last_review 0
# reviews_per_month 0
# calculated_host_listings_count 0
# availability_365 0
# number_of_reviews_ltm 0
# license 0
# rating 0
# bedrooms 0
# beds 0
# baths 0

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# license                           0
# rating                            0
# bedrooms                          0
# beds                              0
# baths                             0
# dtype: int64

# %%
df.shape
# Out:
# (20763, 22)

# %%
#voir le nombre de doublons les doublons
#df.duplicated().sum()
#df[df.duplicated()]
#df.duplicated().sum()
#df.duplicates(inplace=True)
# afficher les lignes ou il y a de doublons
df[df.duplicated()].head()
# Out:
#               id                                               name  \
# 6   4.527754e+07  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 7   9.710000e+17  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 8   3.857863e+06  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 9   4.089661e+07  Condo in New York · ★4.91 · Studio · 1 bed · 1...
# 10  4.958498e+07  Rental unit in New York · ★5.0 · 1 bedroom · 1...
#
#       host_id           host_name neighbourhood_group       neighbourhood  \
# 6    51501835            Jeniffer           Manhattan      Hell's Kitchen
# 7   528871354              Joshua           Manhattan             Chelsea
# 8    19902271  John And Catherine           Manhattan  Washington Heights
# 9    61391963      Stay With Vibe           Manhattan         Murray Hill
# 10   51501835            Jeniffer           Manhattan      Hell's Kitchen
#
#      latitude  longitude        room_type  price  ...  last_review  \
# ...

# %%
#df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#voir les types de vraibles pour chaque columns
df.dtypes

df['id']= df['id'].astype(object)

# %%
#changer le type de id qui est  en float en object
df['id']= df['id'].astype(object)

# %%
df.dtypes
# Out:
# id                                 object
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm             float64
# license                            object
# rating                             object
# bedrooms                           object
# beds                                int64
# baths                              object
# dtype: object

# %% [markdown]
# ***Data Analysis***
# *faire une analyse univaririe*

# %% [markdown]
# **Distribution du prix**

# %%
df['price']
# Out:
# 0         55.0
# 1        144.0
# 2        187.0
# 3        120.0
# 4         85.0
#          ...
# 20765     45.0
# 20766    105.0
# 20767    299.0
# 20768    115.0
# 20769    102.0
# Name: price, Length: 20751, dtype: float64

# %%
sns.histplot(data=df, x='price')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
# identifier les valeurs outliers pour les prix
sns.boxplot(data=df, x='price')
# Out:
# <Axes: xlabel='price'>

# %%
data = df[df['price']<1500]

# %%
sns.boxplot(data=data, x='price')
# Out:
# <Axes: xlabel='price'>

# %%
plt.figure(figsize=(5,5))
sns.histplot(data=data, x='price')
plt.ylabel('Frequence')
# Out:
# Text(0, 0.5, 'Frequence')

# %%
df.dtypes
# Out:
# id                                 object
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm             float64
# license                            object
# rating                             object
# bedrooms                           object
# beds                                int64
# baths                              object
# dtype: object

# %%
plt.figure(figsize=(6,6))
sns.histplot(data=df, x='availability_365')
plt.title('availability_365 distribution')
plt.ylabel('Frequence')
# Out:
# Text(0, 0.5, 'Frequence')

# %%
df.groupby(by='neighbourhood_group')['price'].mean()
# Out:
# neighbourhood_group
# Bronx            118.407798
# Brooklyn         187.198058
# Manhattan        227.566131
# Queens           126.553956
# Staten Island    118.780069
# Name: price, dtype: float64

# %% [markdown]
# **Feature Enginnerring**

# %%
df['price per bed'] = df['price']/df['beds']

# %%
df.head()
# Out:
#                      id                                               name  \
# 0             1312228.0         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1            45277537.0  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2  971000000000000000.0  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3             3857863.0  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 4            40896611.0  Condo in New York · ★4.91 · Studio · 1 bed · 1...
#
#      host_id           host_name neighbourhood_group       neighbourhood  \
# 0    7130382              Walter            Brooklyn        Clinton Hill
# 1   51501835            Jeniffer           Manhattan      Hell's Kitchen
# 2  528871354              Joshua           Manhattan             Chelsea
# 3   19902271  John And Catherine           Manhattan  Washington Heights
# 4   61391963      Stay With Vibe           Manhattan         Murray Hill
#
#     latitude  longitude        room_type  price  ...  reviews_per_month  \
# ...

# %%
df.groupby(by='neighbourhood_group')['price per bed'].mean()
# Out:
# neighbourhood_group
# Bronx             85.165996
# Brooklyn         128.405625
# Manhattan        151.917751
# Queens            78.565703
# Staten Island     67.728101
# Name: price per bed, dtype: float64

# %% [markdown]
# **analyse bivariee**

# %%
#comment une colonne depend d'une autre
plt.figure(figsize=(5,6))
sns.barplot(data=data, x='neighbourhood_group', y='price', hue='room_type')
plt.title('price per neighbourhood_group')
# Out:
# Text(0.5, 1.0, 'price per neighbourhood_group')

# %%
#review and price relationship
sns.scatterplot(data=data, x='number_of_reviews', y='price', hue='neighbourhood_group')
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='price'>

# %%
sns.pairplot(
    data=df,
    vars=['price', 'minimum_nights', 'number_of_reviews', 'availability_365'],
    hue='room_type',
    plot_kws={'alpha': 0.5}
)

# %%
# distribution geographique
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='longitude',y='latitude', hue='room_type')
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
corr = df[
    [
        'longitude',
        'latitude',
        'price',
        'minimum_nights',
        'number_of_reviews',
        'reviews_per_month',
        'availability_365',
        'beds'
    ]
].corr()

corr
# Out:
#                    longitude  latitude     price  minimum_nights  \
# longitude           1.000000  0.046317 -0.033418        0.024114
# latitude            0.046317  1.000000 -0.001256        0.004173
# price              -0.033418 -0.001256  1.000000       -0.006437
# minimum_nights      0.024114  0.004173 -0.006437        1.000000
# number_of_reviews   0.005834 -0.048244 -0.012608       -0.059237
# reviews_per_month   0.042603 -0.041924 -0.009961       -0.122540
# availability_365    0.061802 -0.005202  0.020112        0.034524
# beds                0.035766 -0.070388  0.066258       -0.026335
#
#                    number_of_reviews  reviews_per_month  availability_365  \
# longitude                   0.005834           0.042603          0.061802
# latitude                   -0.048244          -0.041924         -0.005202
# price                      -0.012608          -0.009961          0.020112
# minimum_nights             -0.059237          -0.122540          0.034524
# ...

# %%
plt.figure(figsize=(10, 8))

sns.heatmap(
    corr,
    annot=True,
    #fmt=".2f",
    #cmap="coolwarm",
    #linewidths=0.5
)

plt.title("Matrice de corrélation des variables")
plt.show()
